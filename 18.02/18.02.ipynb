# %%
library(dplyr)
library(ggplot2)
library(RColorBrewer)
library(DAAG)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Error in library(DAAG): there is no package called ‘DAAG’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
finch_12 <- read.csv("18.02/finch_beaks_1975.csv")
finch_75 <- read.csv("18.02/finch_beaks_2012.csv")

# %%
colnames(finch_75) <- colnames(finch_12)

# %%
finch_12$year <- 2012
finch_75$year <- 1975

# %%
finch_full <- rbind(finch_12, finch_75)
finch_full$year <- as.factor(finch_full$year)
